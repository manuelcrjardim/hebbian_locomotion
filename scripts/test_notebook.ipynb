# %%
import matplotlib.pyplot as plt

# %%
import pickle
import torch

# %%
file_path = '/cs/student/project_msc/2025/rai/mdecastr/Isaac_Lab/isaac_lab_sandbox/workspace/hebbian_locomotion/checkpoints/hebbian_es_checkpoint_100.pickle'

with open(file_path, 'rb') as file:
    models = pickle.load(file)

print('length of file:', len(models))

print('\n Solver:', models[0])

print('\n Models:', models[1])

print('\n Len of pop_mean_curve:', len(models[2]), '\n Pop_mean_curve:', models[2])

print('\n Len of best_sol_curver:', len(models[3]), '\n best_sol_curve:', models[3])
# Out:
# length of file: 4
#
#  Solver: <hebbian_locomotion.networks.ES_classes.OpenES object at 0x7f9d3c115690>
#
#  Models: <hebbian_locomotion.networks.hebbian_neural_net.HebbianNet object at 0x7f9be8c242d0>
#
#  Len of pop_mean_curve: 500
#  Pop_mean_curve: [-2.90377283 -2.20215082 -2.47116804 -2.28892756 -2.25686836 -2.44475603
#  -2.39160919 -2.38636947 -2.34425116 -2.32496452 -2.3404007  -2.15993881
#  -2.21973968 -2.49022961 -2.13876963 -2.40964699 -2.22817206 -2.24270153
#  -2.29898357 -2.41709638 -2.05569029 -2.35389638 -2.12293243 -2.54020691
#  -2.45640755 -2.1786232  -2.2611208  -2.42241192 -2.27285814 -2.17381549
#  -2.29756403 -2.07056475 -2.13268471 -2.12544584 -2.42849946 -2.07709408
#  -2.33252001 -2.41379547 -2.047544   -2.16497993 -2.42829275 -2.35527682
#  -2.30797291 -2.23668289 -2.16927695 -2.50468326 -2.34843421 -2.34472227
#  -2.29118705 -2.39639044 -2.36252737 -2.25740862 -2.29288721 -2.07269931
# ...

# %%
mean_rewards = models[2][:100]
best_rewards = models[3][:100]

# %%
plt.plot(mean_rewards)

# %%
plt.plot(best_rewards)
